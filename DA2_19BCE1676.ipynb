# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
#Word Segmentation
stop_words = set(stopwords.words('english'))
content = "I have a dream that one day on the red hills of Georgia, the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood. Land where my fathers died, land of the Pilgrim's pride, From every mountainside, let freedom ring! And so let freedom ring from the prodigious hilltops of New Hampshire. Let freedom ring from the mighty mountains of New York. With this faith, we will be able to work together, to pray together, to struggle together, to go to jail together, to stand up for freedom together, knowing that we will be free one day. And this will be the day when all of God’s children will be able to sing with new meaning. And when this happens, when we allow freedom ring, when we let it ring from every village and every hamlet, from every state and every city, we will be able to speed up that day when all of God s children, black men and white men, Jews and Gentiles, Protestants and Catholics, will be able to join hands and sing in the words of the old Negro spiritual. Freedom, Freedom, Freedom!"
word_tokens = word_tokenize(content)
print(word_tokens)
# Out:
# ['I', 'have', 'a', 'dream', 'that', 'one', 'day', 'on', 'the', 'red', 'hills', 'of', 'Georgia', ',', 'the', 'sons', 'of', 'former', 'slaves', 'and', 'the', 'sons', 'of', 'former', 'slave', 'owners', 'will', 'be', 'able', 'to', 'sit', 'down', 'together', 'at', 'the', 'table', 'of', 'brotherhood', '.', 'Land', 'where', 'my', 'fathers', 'died', ',', 'land', 'of', 'the', 'Pilgrim', "'s", 'pride', ',', 'From', 'every', 'mountainside', ',', 'let', 'freedom', 'ring', '!', 'And', 'so', 'let', 'freedom', 'ring', 'from', 'the', 'prodigious', 'hilltops', 'of', 'New', 'Hampshire', '.', 'Let', 'freedom', 'ring', 'from', 'the', 'mighty', 'mountains', 'of', 'New', 'York', '.', 'With', 'this', 'faith', ',', 'we', 'will', 'be', 'able', 'to', 'work', 'together', ',', 'to', 'pray', 'together', ',', 'to', 'struggle', 'together', ',', 'to', 'go', 'to', 'jail', 'together', ',', 'to', 'stand', 'up', 'for', 'freedom', 'together', ',', 'knowing', 'that', 'we', 'will', 'be', 'free', 'one', 'day', '.', 'And', 
# ...

# %%
#Sentence Segmentation
sent_tokens = sent_tokenize(content)
print(sent_tokens)
# Out:
# ['I have a dream that one day on the red hills of Georgia, the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood.', "Land where my fathers died, land of the Pilgrim's pride, From every mountainside, let freedom ring!", 'And so let freedom ring from the prodigious hilltops of New Hampshire.', 'Let freedom ring from the mighty mountains of New York.', 'With this faith, we will be able to work together, to pray together, to struggle together, to go to jail together, to stand up for freedom together, knowing that we will be free one day.', 'And this will be the day when all of God’s children will be able to sing with new meaning.', 'And when this happens, when we allow freedom ring, when we let it ring from every village and every hamlet, from every state and every city, we will be able to speed up that day when all of God s children, black men and white men, Jews and Gentiles, Protestants and Catholics, will be able t
# ...

# %%
#Lowercase
content.lower()
# Out:
# "i have a dream that one day on the red hills of georgia, the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood. land where my fathers died, land of the pilgrim's pride, from every mountainside, let freedom ring! and so let freedom ring from the prodigious hilltops of new hampshire. let freedom ring from the mighty mountains of new york. with this faith, we will be able to work together, to pray together, to struggle together, to go to jail together, to stand up for freedom together, knowing that we will be free one day. and this will be the day when all of god’s children will be able to sing with new meaning. and when this happens, when we allow freedom ring, when we let it ring from every village and every hamlet, from every state and every city, we will be able to speed up that day when all of god s children, black men and white men, jews and gentiles, protestants and catholics, will be able to join hands and si
# ...

# %%
#Stop Words Removal

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  
filtered_sentence = []
  
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
  
print(word_tokens)
print(filtered_sentence)
# Out:
# ['I', 'have', 'a', 'dream', 'that', 'one', 'day', 'on', 'the', 'red', 'hills', 'of', 'Georgia', ',', 'the', 'sons', 'of', 'former', 'slaves', 'and', 'the', 'sons', 'of', 'former', 'slave', 'owners', 'will', 'be', 'able', 'to', 'sit', 'down', 'together', 'at', 'the', 'table', 'of', 'brotherhood', '.', 'Land', 'where', 'my', 'fathers', 'died', ',', 'land', 'of', 'the', 'Pilgrim', "'s", 'pride', ',', 'From', 'every', 'mountainside', ',', 'let', 'freedom', 'ring', '!', 'And', 'so', 'let', 'freedom', 'ring', 'from', 'the', 'prodigious', 'hilltops', 'of', 'New', 'Hampshire', '.', 'Let', 'freedom', 'ring', 'from', 'the', 'mighty', 'mountains', 'of', 'New', 'York', '.', 'With', 'this', 'faith', ',', 'we', 'will', 'be', 'able', 'to', 'work', 'together', ',', 'to', 'pray', 'together', ',', 'to', 'struggle', 'together', ',', 'to', 'go', 'to', 'jail', 'together', ',', 'to', 'stand', 'up', 'for', 'freedom', 'together', ',', 'knowing', 'that', 'we', 'will', 'be', 'free', 'one', 'day', '.', 'And', 
# ...

# %%
#Stemming
ps = PorterStemmer()
 
for w in word_tokens:
    print(w, " : ", ps.stem(w))
# Out:
# I  :  i
# have  :  have
# a  :  a
# dream  :  dream
# that  :  that
# one  :  one
# day  :  day
# on  :  on
# the  :  the
# red  :  red
# hills  :  hill
# of  :  of
# Georgia  :  georgia
# ,  :  ,
# the  :  the
# sons  :  son
# of  :  of
# former  :  former
# slaves  :  slave
# and  :  and
# the  :  the
# sons  :  son
# of  :  of
# former  :  former
# slave  :  slave
# owners  :  owner
# will  :  will
# be  :  be
# able  :  abl
# to  :  to
# sit  :  sit
# down  :  down
# together  :  togeth
# at  :  at
# the  :  the
# table  :  tabl
# of  :  of
# brotherhood  :  brotherhood
# .  :  .
# Land  :  land
# where  :  where
# my  :  my
# fathers  :  father
# died  :  die
# ,  :  ,
# land  :  land
# of  :  of
# the  :  the
# Pilgrim  :  pilgrim
# 's  :  's
# pride  :  pride
# ,  :  ,
# From  :  from
# every  :  everi
# mountainside  :  mountainsid
# ,  :  ,
# let  :  let
# freedom  :  freedom
# ring  :  ring
# !  :  !
# And  :  and
# so  :  so
# let  :  let
# freedom  :  freedom
# ...

# %%
#Lemmatization
lemmatizer = WordNetLemmatizer()
  
for w in word_tokens:
    print(w + " :", lemmatizer.lemmatize(w))
    # a denotes adjective in "pos"
#     print(w + " :", lemmatizer.lemmatize(w, pos ="a"))
# Out:
# I : I
# have : have
# a : a
# dream : dream
# that : that
# one : one
# day : day
# on : on
# the : the
# red : red
# hills : hill
# of : of
# Georgia : Georgia
# , : ,
# the : the
# sons : son
# of : of
# former : former
# slaves : slave
# and : and
# the : the
# sons : son
# of : of
# former : former
# slave : slave
# owners : owner
# will : will
# be : be
# able : able
# to : to
# sit : sit
# down : down
# together : together
# at : at
# the : the
# table : table
# of : of
# brotherhood : brotherhood
# . : .
# Land : Land
# where : where
# my : my
# fathers : father
# died : died
# , : ,
# land : land
# of : of
# the : the
# Pilgrim : Pilgrim
# 's : 's
# pride : pride
# , : ,
# From : From
# every : every
# mountainside : mountainside
# , : ,
# let : let
# freedom : freedom
# ring : ring
# ! : !
# And : And
# so : so
# let : let
# freedom : freedom
# ring : ring
# from : from
# the : the
# prodigious : prodigious
# hilltops : hilltop
# of : of
# New : New
# Hampshire : Hampshire
# ...

# %%
#Part of Speech Tagger
tagged = nltk.pos_tag(filtered_sentence)
print(tagged)
# Out:
# [('I', 'PRP'), ('dream', 'VBP'), ('one', 'CD'), ('day', 'NN'), ('red', 'JJ'), ('hills', 'NNS'), ('Georgia', 'NNP'), (',', ','), ('sons', 'NNS'), ('former', 'JJ'), ('slaves', 'NNS'), ('sons', 'NNS'), ('former', 'JJ'), ('slave', 'VBP'), ('owners', 'NNS'), ('able', 'JJ'), ('sit', 'NN'), ('together', 'RB'), ('table', 'JJ'), ('brotherhood', 'NN'), ('.', '.'), ('Land', 'NNP'), ('fathers', 'NNS'), ('died', 'VBD'), (',', ','), ('land', 'VBP'), ('Pilgrim', 'NNP'), ("'s", 'POS'), ('pride', 'NN'), (',', ','), ('From', 'IN'), ('every', 'DT'), ('mountainside', 'NN'), (',', ','), ('let', 'VB'), ('freedom', 'NN'), ('ring', 'VBG'), ('!', '.'), ('And', 'CC'), ('let', 'VB'), ('freedom', 'NN'), ('ring', 'VBG'), ('prodigious', 'JJ'), ('hilltops', 'NNS'), ('New', 'NNP'), ('Hampshire', 'NNP'), ('.', '.'), ('Let', 'VB'), ('freedom', 'JJ'), ('ring', 'VBG'), ('mighty', 'NN'), ('mountains', 'VBZ'), ('New', 'NNP'), ('York', 'NNP'), ('.', '.'), ('With', 'IN'), ('faith', 'NN'), (',', ','), ('able', 'JJ'), ('work
# ...
